# %%
#import libraries
import pandas as pd
# pip install pandas
import matplotlib.pyplot as plt
import numpy as np

# %%
path_source = 'supermarket_sales - Sheet1.csv'
df_sales = pd.read_csv(path_source)
df_sales.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df_sales.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
# df_sales.head(10)
df_sales.tail(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
#distinct values and count
df_sales['Branch'].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
#get rows
df_sales.loc[2]
df_sales[1:2]
df_sales[50:]
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 50   326-78-5178      C  Naypyitaw        Member    Male   Food and beverages
# 51   162-48-8011      A     Yangon        Member  Female   Food and beverages
# 52   616-24-2851      B   Mandalay        Member  Female  Fashion accessories
# 53   778-71-5554      C  Naypyitaw        Member    Male  Fashion accessories
# 54   242-55-6721      B   Mandalay        Normal    Male   Home and lifestyle
# ..           ...    ...        ...           ...     ...                  ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
# ...

# %%
#sorting
df_sales.sort_values('Rating')
#desc
df_sales.sort_values('Rating', ascending = False)
#sort rating asc then gross income desc
df_sales.sort_values(['Rating', 'gross income'], ascending = [False, True])
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 60   285-68-5083      C  Naypyitaw        Member  Female
# 387  725-56-0833      A     Yangon        Normal  Female
# 62   347-34-2234      B   Mandalay        Member  Female
# 853  866-70-2814      B   Mandalay        Normal  Female
# 159  423-57-2993      B   Mandalay        Normal    Male
# ..           ...    ...        ...           ...     ...
# 643  131-15-8856      C  Naypyitaw        Member  Female
# 85   730-50-9884      C  Naypyitaw        Normal  Female
# 618  828-46-6863      A     Yangon        Member    Male
# 226  836-82-5858      B   Mandalay        Member    Male
# 848  845-94-6841      C  Naypyitaw        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 60        Sports and travel       24.74         3   3.7110   77.9310
# 387       Health and beauty       32.32        10  16.1600  339.3600
# 62        Sports and travel       55.07         9  24.7815  520.4115
# ...

# %%
df_sales.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df_sales['gross income'].sum()
# Out:
# 15379.368999999999

# %%
print("Dữ liệu trước khi scale")
print(df_sales.head(2))
print("\n-------------\nDữ liệu sau khi scale")
df_sales['Rating Scale'] = df_sales['Rating']*10
print(df_sales.head(2))
# Out:
# Dữ liệu trước khi scale
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
#
#     Time  Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08  Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29     Cash   76.40                 4.761905        3.8200     9.6
#
# -------------
# Dữ liệu sau khi scale
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# ...

# %%
df_sales[(df_sales['Branch']=='A') & (df_sales['City']=='Yangon')]
# Out:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2    631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3    123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4    373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6    355-53-5943      A  Yangon        Member  Female  Electronic accessories
# ..           ...    ...     ...           ...     ...                     ...
# 990  886-18-2897      A  Yangon        Normal  Female      Food and beverages
# 992  745-74-0715      A  Yangon        Normal    Male  Electronic accessories
# 997  727-02-1313      A  Yangon        Member    Male      Food and beverages
# 998  347-56-2442      A  Yangon        Normal    Male      Home and lifestyle
# 999  849-09-3807      A  Yangon        Member  Female     Fashion accessories
#
# ...

# %%
#split into 2 tables
df_branch = df_sales[['Branch', 'City']]
df_branch.drop_duplicates(inplace=True)

df_sales_v2 =  df_sales.drop('City', axis=1)
df_sales_v2
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_5648/2194019933.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_branch.drop_duplicates(inplace=True)
#       Invoice ID Branch Customer type  Gender            Product line  \
# 0    750-67-8428      A        Member  Female       Health and beauty
# 1    226-31-3081      C        Normal  Female  Electronic accessories
# 2    631-41-3108      A        Normal    Male      Home and lifestyle
# 3    123-19-1176      A        Member    Male       Health and beauty
# 4    373-73-7910      A        Normal    Male       Sports and travel
# ..           ...    ...           ...     ...                     ...
# 995  233-67-5758      C        Normal    Male       Health and beauty
# 996  303-96-2227      B        Normal  Female      Home and lifestyle
# ...

# %%
df_join = pd.merge(df_sales_v2, df_branch, on='Branch')
df_join
# Out:
#       Invoice ID Branch Customer type  Gender            Product line  \
# 0    750-67-8428      A        Member  Female       Health and beauty
# 1    631-41-3108      A        Normal    Male      Home and lifestyle
# 2    123-19-1176      A        Member    Male       Health and beauty
# 3    373-73-7910      A        Normal    Male       Sports and travel
# 4    355-53-5943      A        Member  Female  Electronic accessories
# ..           ...    ...           ...     ...                     ...
# 995  552-44-5977      B        Member    Male       Health and beauty
# 996  430-53-4718      B        Member    Male       Health and beauty
# 997  602-16-6955      B        Normal  Female       Sports and travel
# 998  690-01-6631      B        Normal    Male     Fashion accessories
# 999  303-96-2227      B        Normal  Female      Home and lifestyle
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# ...

# %% [markdown]
# Vẽ chart
#
# x:brannch
#
# y: gross sale
#
# line: avg rating

# %%
df_chart = df_sales_v2.groupby('Branch').agg({'gross income': sum, 'Rating': 'mean'})
df_chart
# Out:
#         gross income    Rating
# Branch
# A          5057.1605  7.027059
# B          5057.0320  6.818072
# C          5265.1765  7.072866

# %%
plt.rcParams["figure.figsize"] = [8, 5]
plt.rcParams["figure.autolayout"] = True
fig, ax = plt.subplots()

df_chart['gross income'].plot(kind='bar', color='#DF9496')
df_chart['Rating'].plot(secondary_y = True, marker='*', color='#727B84')

plt.show()
